# %%
import pandas as pd

# %% [markdown]
# # Input country name and desc

# %%
country = input('tap country name : ')
print('\n')
descruption_input = input('tap descruption :\n')
# Out:
# tap country name : Qatar
#
#
# tap descruption :
# The Digital Farmer Community project deploys a community platform providing localized agriculture information and crop-specific advice for farmers leveraging IoT and satellite technology. It offers a wide array of services ranging from disease recognition & prevention to crop health analytics & monitoring. Expected impact The Digital Farmer Community solution will empower farmers to increase local food production and profits and enhance produce quality Website https://tasmu.gov.qa/en

# %% [markdown]
# # Read and clean data

# %%
data = pd.read_csv('Cleaned_SDG_Partnerships.csv')
data.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1                                      goal  \
# 0           0             0  End poverty in all its forms everywhere.
# 1           1             1  End poverty in all its forms everywhere.
# 2           2             2  End poverty in all its forms everywhere.
# 3           3             3  End poverty in all its forms everywhere.
# 4           4             4  End poverty in all its forms everywhere.
#
#                                  name_of_partnership  \
# 0  Water/ocean governance thought leadership, the...
# 1                 The Sustainable Fashion Collective
# 2  Responsible Sourcing Policy (RSP) for Tuna fis...
# 3  Scaling up a sustainable solution for safe dri...
# 4                                         The Canvas
#
#                                                 link           start_date  \
# 0  https://sustainabledevelopment.un.org/partners...  2019-01-01 00:00:00
# 1  https://sustainabledevelopment.un.org/partners...  2017-01-01 00:00:00
# 2  https://sustainabledevelopment.un.org/partners...  2017-08-01 00:00:00
# 3  https://sustainabledevelopment.un.org/partners...  2019-01-01 00:00:00
# 4  https://sustainabledevelopment.un.org/partners...  2021-05-01 00:00:00
#
#               end_date                                             entity  \
# 0  2023-12-31 00:00:00  UNDP-SIWI Water Governance Facility (Partnership)
# 1  2030-12-01 00:00:00                                                NaN
# 2  2022-12-01 00:00:00                                                NaN
# 3  2030-12-31 00:00:00  1001fontaines (Non-governmental organization (...
# 4  2030-12-31 00:00:00                                                NaN
#
#                                             partners  \
# 0  UNDP-SIWI Water Governance Facility (partnersh...
# 1                                   Offset Warehouse
# 2  (https://www.fia-png.com/) (https://fishchoice...
# 3  - 1001fontaines (NGO)\r - Teuk Saat 1001 (NGO)...
# 4  3QUARTERS, DOTMO (Distant Relatives), Abby All...
#
#                                geographical_coverage  \
# 0  AfricaAsia and PacificGlobalLatin America and ...
# 1                                                NaN
# 2                                                NaN
# 3                             AfricaAsia and Pacific
# 4                                                NaN
#
#                                beneficiary_countries contact_information  \
# 0  Armenia\r \r \r Bangladesh\r \r \r Cambodia\r ...   Stockholm, Sweden
# 1                                                NaN                 NaN
# 2                                                NaN                 NaN
# 3  Cambodia\r \r \r Madagascar\r \r \r Myanmar\r ...       Paris, France
# 4                                                NaN                 NaN
#
#                                         headquarters  \
# 0  Birgitta Liss Lymer, Director, WGF, birgitta.l...
# 1  Charlie Bradley Ross, Director, charlie@offset...
# 2  Marcelo Hidalgo, Sustainability Director, cont...
# 3  Eva Leneveu, Partnerships and advocacy officer...
# 4  Devin Gilmartin, Co-Chief Executive Officer, d...
#
#                                          description start_year end_year  \
# 0  Description                              The U...       2019     2023
# 1  Description/achievement of initiative  An onli...       2017     2030
# 2  PNG Fishing Industry Association  (PNG FIA) is...       2017     2022
# 3  Description                              For t...       2019     2030
# 4  Description/achievement of initiative  The Can...       2021     2030
#
#   partnership_term_period
# 0                       4
# 1                      13
# 2                       5
# 3                      11
# 4                       9

# %%
data = data.drop_duplicates(subset='description', keep="last")

# %%
data[data['contact_information'].notna()]['contact_information'].unique()
# Out:
# array(['Bangui, République Centrafricaine', 'Doha, Qatar',
#        'Lilongwe, Malawi', 'Ilorin Nigeria', 'Ontario, California',
#        'Tilonia Village, Ajmer district, Rajasthan, India - 305816.',
#        'Port-au-prince, Haiti', 'MELBOURNE, VICTORIA, AUSTRALIA',
#        'Sao Paulo, Brazil', 'Ankara', 'Tokyo, Japan',
#        'Diamniadio/Dakar, Sénégal',
#        '7576 Mkosana T/ Ship Victoria Falls Zimbabwe',
#        'Empire building shop 6 corner JNKhomo street and 6th avenue bulawayo zimbabwe',
#        'Harare', 'Bulawayo, Zimbabwe', 'London, United Kingdom',
#        'Kinshasa, Democratic Republic of Congo',
#        'BROOKLY NEW YORK UNITED STATE', 'Harare, Zimbabwe',
#        'East Kilbride/London, United Kingdom', 'Beijing, China',
#        'Karpala / Ouagadougou, Burkina Faso', 'Netanya, Israel',
#        'Global Water Partnership, Stockholm, Sweden',
#        'University of Southeastern Norway, Bakkenteigen. 3186 Horten. Norway',
#        'Nairobi', 'Minsk, Belarus',
#        'UNDP Istanbul Regional Hub, Istanbul, Turkey', 'Bangalore, India',
#        'New York', 'The Netherlands', 'Geneva, Switzerland',
#        'New Delhi, India', 'Sydney, Australia', 'Marsabit/Nairobi- Kenya',
#        'Vernier, Geneva - SWITZERLAND', 'Gland, Switzerland',
#        'Ulaanbaatar, Mongolia', 'Mexico', 'Madrid, Spain', 'Dubai, UAE',
#        'Vienna, Austria', 'Cheyenne, USA', 'New York, USA',
#        'Conakry, République de Guinée', 'Paris/France',
#        'Metro Manila, Philippines', 'San Francisco, CA USA',
#        'Amsterdam, The Netherlands', 'Amsterdam, the Netherlands',
#        'Nairobi, Kenya', 'Kazan, Russian Federation',
#        'Nasr City, Cairo, Egypt', 'London', 'Geneva',
#        'Mandaluyong, Philippines', 'Bangkok, Thailand',
#        'Bridgeport, Connecticut, United States', 'Johannesburg',
#        'Washington D.C, Columbia, United States',
#        'The Hague, The Netherlands', 'Al-Ahsaa, Saudi Arabia',
#        'Balikesir, Turkey',
#        'Office of the Mayor of Bogotá-  International Relations Division - Bogotá, Colombia',
#        'Genk, Belgium', 'city of rabat/morocco',
#        'Los Angeles, United States',
#        'Esikhaleni (Richards Bay) South Africa', 'Barcelona, Spain',
#        'London, UK', 'cabo verde', 'Dubai, United Arab Emirates',
#        'Centre coulbaly sidiki/Université de Kinshasa', 'Spain',
#        'Phoenix, Arizona, USA', 'C/. Navarra, #2 - 01007 VITORIA- Spain',
#        'Nairobi-Kenya', 'Shibuya, Tokyo, Japan', 'Helsinki/Finland',
#        'Helsinki, Finland', 'Stockholm, Sweden', 'Paris, France',
#        'Guildford, United Kingdom', 'Eniwacity,Hokkaido/Japan', 'India',
#        'Rome, Italy', 'Marrakech, Morocco', 'KAMPALA, UGANDA',
#        'Buffalo, NY, USA', 'Mali/Bamako', 'Eindhoven, The Netherlands',
#        'Abuja', 'Hamburg, Germany',
#        '16 Liberty House, 50 K.Kaunda Street Harare, Zimbabwe',
#        'NEW YORK', 'Hanoi, Vietnam',
#        'Permanent Mission of Liechtenstein to the United Nations in New York',
#        'Osaka, Japan', 'New York City, USA', 'Ibadan, Nigeria',
#        'Quito, Ecuador', 'Wilmington, Delaware, United States',
#        'Rabat, Morocco', '61987', 'Paris', 'Amsterdam, Netherlands',
#        'London, the United Kingdon', 'Puno, Perú', 'Guatemala, Guatemala',
#        'Bukavu, DR Congo', 'SURAT, India', 'Piura, Perú', 'NDjamena/Chad',
#        'Honolulu, USA', 'Rio de Janeiro, Brazil', 'Nicosia,  Cyprus',
#        'Madrid, Spain (IAHR Secretariat)', 'Berlin, Germany',
#        'Ipoh, Malaysia', 'Boulder, CO, USA',
#        'BANSTOLVÄGEN 2, 75648, UPPSALA, SWEDEN', 'Pretoria, South Africa',
#        'LAGOS, NIGERIA', 'Bulawayo,Zimbabwe', 'Bogota, Colombia',
#        'Milan - Italy', 'Seoul, Korea', 'Kampala Uganda',
#        "Rajputana's Shakuntalam, Village Ramnagar, PO Mallah, Bharatpur 321001 Rajasthan, India",
#        'Beirut, Lebanon', 'New York, NY, USA', 'Warsaw, Poland',
#        'Los Angeles, CA, USA', 'Nagoya, Japan', 'Vienna/Austria',
#        'Delhi, India', 'Formas (Stockholm, Sweden)',
#        'EYYÜBİYE/ŞANLIURFA/TURKEY', 'Liverpool, UK', 'Lima, Peru',
#        'Mexico City', 'Rabat/Morocco', 'Dhaka | Bangladesh', 'Peru',
#        'THE GAMBIA', 'Peru, Lima', 'Bamako/ District, Mali',
#        'Pachuca de Soto, Hidalgo, México',
#        'LAPFUND GARDENS- NAIROBI KENYA', 'Abuja, Nigeria',
#        'República de Panamá, Ciudad de Panamá, Via Ricardo J. Alfaro, Edificio Edison Plaza, 4to piso',
#        'Zvishavane', 'Amuria District, Uganda', 'Libreville-Gabon',
#        'Port Louis, Mauritius', 'KAMPALA - UGANDA',
#        'San José, Costa Rica', 'Americana/Sao Paulo, Brazil',
#        'Nairobi,Hazina Towers', 'Kabul, Afghanistan', 'Munich, Germany',
#        'Brussels, Belgium', 'Valencia, CA, USA',
#        'OWERRI,  IMO STATE, NIGERIA.', 'NEW DELHI',
#        'San Lorenzo, Valle, Honduras', 'Washington DC, USA',
#        'Mexico, City, MEx', 'Copenhagen, Denmark', 'Lomé-Togo',
#        'Silver Spring, MD', 'gaborone, botswana',
#        'Mandaluyong City, Philippines', 'New York, United States',
#        'UNDP Mexico Country Office',
#        'Hellenic Ministry of Environment and Energy, 119, Mesogeion Av., 101 92 Athens, GREECE',
#        'City of Buenos Aires', 'Justice Canada',
#        '35 Lower Marsh, London SE1 7RL, United Kingdom',
#        'St. John’s Antigua', 'Washington, DC, United States',
#        'Colombo, Sri Lanka', 'NY, USA', 'Ankara Turkey', 'lisbon',
#        'Washington DC, United States of America',
#        'Buenos Aires, Argentina.', 'New York, United States of America',
#        'c/o Earth System Governance International Project Office, Utrecht University, Faculty of Geosciences, Princetonlaan 8a, 3584 CB Utrecht, The Netherlands',
#        'New York, New York, United States of America', 'Manchester, UK',
#        'Washington DC', 'Philippines', 'The Hague',
#        '150 Carey street iCampus Monrovia, Liberia', 'Jos, Nigeria',
#        'Norwich, U.K.', 'Bogura', 'Santiago, Chile',
#        'ESCWA (Beirut, LEBANON)', 'Rio de Janeiro, RJ - Brazil',
#        'Toronto, Canada', 'Istanbul / Turkiye', 'Germany',
#        'Kinshasa, République Démocratique du Congo',
#        'West PokotCounty,Kenya'], dtype=object)

# %%
data = data[data['contact_information'].notna()]
data['country_name'] = data['contact_information'].apply(lambda x : x.replace('/',',').split(',')[-1].replace(' ','') if len(x.replace('/',',').split(','))>1 else x)
data.head()
# Out:
#      Unnamed: 0  Unnamed: 0.1  \
# 76           76            76
# 862         862           862
# 863         863           863
# 891         891           891
# 916         916           916
#
#                                                   goal  \
# 76            End poverty in all its forms everywhere.
# 862  End hunger, achieve food security and improved...
# 863  End hunger, achieve food security and improved...
# 891  End hunger, achieve food security and improved...
# 916  End hunger, achieve food security and improved...
#
#                                    name_of_partnership  \
# 76   Renforcement des capacités productives, Commer...
# 862              National Food Safety Analytics (NFSA)
# 863                     Digital Farmer Community (DFC)
# 891  Joint UN Programme: Social Protection for the ...
# 916                       GSFEN for the Poor in Africa
#
#                                                   link           start_date  \
# 76   https://sustainabledevelopment.un.org/partners...  2020-09-09 00:00:00
# 862  https://sustainabledevelopment.un.org/partners...  2020-04-01 00:00:00
# 863  https://sustainabledevelopment.un.org/partners...  2020-03-01 00:00:00
# 891  https://sustainabledevelopment.un.org/partners...  2020-01-01 00:00:00
# 916  https://sustainabledevelopment.un.org/partners...  2020-06-03 00:00:00
#
#                 end_date                                             entity  \
# 76   2023-08-29 00:00:00  Ministère du Commerce et de l'Industrie/Cellul...
# 862  2021-03-31 00:00:00  Ministry of Transport and Communications (Gove...
# 863  2021-08-31 00:00:00  Ministry of Transport and Communications (Gove...
# 891  2021-12-31 00:00:00  World Food Programme (WFP), United Nations Chi...
# 916  2020-10-01 00:00:00  Global Socio-economic and Financial Evolution ...
#
#                                               partners geographical_coverage  \
# 76   Projet Cadre Intégré Renforcé, Banque Mondiale...                Africa
# 862  Ministry of Transport and Communications, Mini...             West Asia
# 863  Ministry of Transport and Communications, Mini...             West Asia
# 891  World Food Programme (United Nations), UNICEF ...                Africa
# 916                         World Humanitarian Network                Africa
#
#     beneficiary_countries                contact_information  \
# 76                    NaN  Bangui, République Centrafricaine
# 862                 Qatar                        Doha, Qatar
# 863                 Qatar                        Doha, Qatar
# 891                Malawi                   Lilongwe, Malawi
# 916               Nigeria                     Ilorin Nigeria
#
#                                           headquarters  \
# 76   Alain DOUATHE KOYANGOZO, Mr. Expert en Intégra...
# 862  Reem Al-Mansoori, Assistant Undersecretary of ...
# 863  Reem Al-Mansoori, Assistant Undersecretary of ...
# 891  Kendall Naylor, SP4SDG Coordinator, kendall.na...
# 916  Prof. Blessing Lawal, President, info.gsfen@gm...
#
#                                            description start_year end_year  \
# 76   Description                              .Obje...       2020     2023
# 862  Description                              Natio...       2020     2021
# 863  Description                              The D...       2020     2021
# 891  Description                              Socia...       2020     2021
# 916  Description                              Provi...       2020     2020
#
#     partnership_term_period              country_name
# 76                        3  RépubliqueCentrafricaine
# 862                       1                     Qatar
# 863                       1                     Qatar
# 891                       1                    Malawi
# 916                       0            Ilorin Nigeria

# %% [markdown]
# # Get needed data according to country and get description ...

# %%
needed_data = data[['country_name','description','contact_information', "link",'name_of_partnership']]
needed_data['description'] = needed_data['description'].apply(lambda x : ' '.join(x.split()[1:]))
# Out:
# <ipython-input-126-77eda068d886>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   needed_data['description'] = needed_data['description'].apply(lambda x : ' '.join(x.split()[1:]))

# %%
needed_data = needed_data[needed_data['country_name']==country]

# %% [markdown]
# # Tokenize data

# %%
import nltk
import re

tokenized_data = []

for index, row in needed_data.iterrows():
    tokenized_data.append(nltk.word_tokenize(re.sub('[^A-Za-z0-9|-|é]+','', row['description'].replace(' ','é')).replace('é',' ').lower()))

descruption_input = nltk.word_tokenize(re.sub('[^A-Za-z0-9|-|é]+','', descruption_input.replace(' ','é')).replace('é',' ').lower())

# %%
needed_data['toknized_desc'] = tokenized_data

# %% [markdown]
# # Remove stop word

# %%
import nltk
from nltk.corpus import stopwords

stop_words = set(stopwords.words('english'))

filterd_sentences = []

for sent in tokenized_data:
    flt = []
    for w in sent : 
        if w not in stop_words :
            flt.append(w)
            
    filterd_sentences.append(flt)   
    
filterd_des = []
for word in descruption_input:
    if word not in stop_words:
        filterd_des.append(word)

# %% [markdown]
# # Apply lemmatization

# %%
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()

    
lim_result = []
    
for sent in filterd_sentences :
    tmp = []
    for word in sent :
        tmp.append(lemmatizer.lemmatize(word))
    lim_result.append(tmp)
    
lim_input_des = []

for word in filterd_des:
    lim_input_des.append(lemmatizer.lemmatize(word))

# %% [markdown]
# # BOW

# %%
Bow_data = []
all_words = []

for sent in lim_result:
    tmp = {}
    for word in sent:
        if word not in tmp:
            tmp[word] = 0
        tmp[word]+=1
        if word not in all_words:
            all_words.append(word)
    Bow_data.append(tmp)
            
bow_input_desc =  {} 

for word in lim_input_des:
    if word in all_words:
        if word not in bow_input_desc :
            bow_input_desc[word]=0
            
        bow_input_desc[word]+=1

# %% [markdown]
# # WordCloud

# %%
all_words1 = ' '.join(all_words)
from wordcloud import WordCloud
import matplotlib.pyplot as plt 
wordcloud = WordCloud(width=800, height=500, random_state=21, max_font_size=110).generate(all_words1)

plt.figure(figsize=(10, 7))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.show()

# %% [markdown]
# # Get term frequency

# %%
TF_data = []

for sent in Bow_data:
    tmp = []
    for word in all_words : 
        if word in sent :
            tmp.append(sent[word])
        else:
            tmp.append(0)
    TF_data.append(tmp)
    
TF_input_desc = []
    
for word in all_words : 
    if word in bow_input_desc:
        TF_input_desc.append(bow_input_desc[word])
    else:
        TF_input_desc.append(0)

# %%
len(TF_data[0])
# Out:
# 708

# %% [markdown]
# # Train hierarchical clustering

# %%
from sklearn.cluster import AgglomerativeClustering

TF_data.append(TF_input_desc)

cluster = AgglomerativeClustering(n_clusters=2, affinity='euclidean', linkage='ward')
prd = cluster.fit_predict(TF_data)[-1]

# %% [markdown]
# # get nearst partners and get the score

# %%
neighs_ind = [j for j in range(len(cluster.labels_)-1) if cluster.labels_[j]==prd]

# %%
neighs = []

for idx in neighs_ind:
    neighs.append(TF_data[idx])

# %%
name_of_partnership = list(needed_data['name_of_partnership'])
contact_information = list(needed_data['contact_information'])
link = list(needed_data['link'])

# %%
from scipy.stats import pearsonr

neigh_scores = {}

for i in range(len(neighs)):

    neigh_scores[neighs_ind[i]] = pearsonr(TF_data[0],neighs[i])[0]*100

# %%
neigh_scores = {k: v for k, v in sorted(neigh_scores.items(), key=lambda item: item[1],reverse=True)}

# %% [markdown]
# # print results

# %%
most_nearst_partners = list(neigh_scores.keys())
scores = list(neigh_scores.values())

print('Here is the most 10 nearst partenrs \n')

for j in range(10):
    if j>=len(most_nearst_partners):
        break
    id_ = most_nearst_partners[j]
    print('name : ',name_of_partnership[id_],' contact_information :',contact_information[id_],' link : ',link[id_],'\n')
    print('score : ',abs(scores[j]))
    print(' ------ ------- ')
# Out:
# Here is the most 10 nearst partenrs
#
# name :  National Food Safety Analytics (NFSA)  contact_information : Doha, Qatar  link :  https://sustainabledevelopment.un.org/partnership/?p=38028
#
# score :  100.0
#  ------ -------
# name :  Digital Farmer Community (DFC)  contact_information : Doha, Qatar  link :  https://sustainabledevelopment.un.org/partnership/?p=38025
#
# score :  12.003250843217895
#  ------ -------
# name :  THEQA  contact_information : Doha, Qatar  link :  https://sustainabledevelopment.un.org/partnership/?p=38001
#
# score :  6.784516589165901
#  ------ -------
# name :  TASMU Smart Qatar Central Platform  contact_information : Doha, Qatar  link :  https://sustainabledevelopment.un.org/partnership/?p=38016
#
# score :  2.849972212442569
#  ------ -------
# name :  Digital Incubation Center  contact_information : Doha, Qatar  link :  https://sustainabledevelopment.un.org/partnership/?p=37995
#
# score :  2.2088814745563115
#  ------ -------
# name :  Smart Parking  contact_information : Doha, Qatar  link :  https://sustainabledevelopment.un.org/partnership/?p=38022
#
# score :  1.558156063742582
#  ------ -------
# name :  Cyber Safety Program  contact_information : Doha, Qatar  link :  https://sustainabledevelopment.un.org/partnership/?p=38043
#
# score :  0.9603169050951059
#  ------ -------
# name :  Digital Inclusion Working Group, Pledge and Awards  contact_information : Doha, Qatar  link :  https://sustainabledevelopment.un.org/partnership/?p=38040
#
# score :  0.742931768841433
#  ------ -------
# name :  Virtual Consultation  contact_information : Doha, Qatar  link :  https://sustainabledevelopment.un.org/partnership/?p=38019
#
# score :  0.5993777851647083
#  ------ -------
